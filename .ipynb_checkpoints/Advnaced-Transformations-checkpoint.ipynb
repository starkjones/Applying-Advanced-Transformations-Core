# %% [markdown]
# # ***Applying Advanced Transformations***

# %%
# Libraries:

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Importing the OS and JSON Modules:
import os,json

# %%
pwd
# Out:
# 'C:\\Users\\jnate\\OneDrive\\Documents\\Data Enrichment\\Applying-Advanced-Transformations-Core-'

# %%
info = pd.read_csv('C:\\Users\\jnate\\OneDrive\\Documents\\Data Enrichment\\Applying-Advanced-Transformations-Core-\\superhero_info.csv')
info.head(5)
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
info.duplicated().sum()
# Out:
# 0

# %%
info.isna().sum()
# Out:
# Hero|Publisher    0
# Gender            0
# Race              0
# Alignment         0
# Hair color        0
# Eye color         0
# Skin color        0
# Measurements      0
# dtype: int64

# %%
info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hero|Publisher  463 non-null    object
#  1   Gender          463 non-null    object
#  2   Race            463 non-null    object
#  3   Alignment       463 non-null    object
#  4   Hair color      463 non-null    object
#  5   Eye color       463 non-null    object
#  6   Skin color      463 non-null    object
#  7   Measurements    463 non-null    object
# dtypes: object(8)
# memory usage: 29.1+ KB

# %%
info.loc[0, 'Measurements']
# Out:
# "{'Height': '203.0 cm', 'Weight': '441.0 kg'}"

# %%
# The quotes indicate that this is a string 
# To use JSON, we will have to change the single quotes to double quotes:

info['Measurements'] = info['Measurements'].str.replace("'", '"')

info['Measurements']
# Out:
# 0      {"Height": "203.0 cm", "Weight": "441.0 kg"}
# 1       {"Height": "191.0 cm", "Weight": "65.0 kg"}
# 2       {"Height": "185.0 cm", "Weight": "90.0 kg"}
# 3      {"Height": "203.0 cm", "Weight": "441.0 kg"}
# 4      {"Height": "193.0 cm", "Weight": "122.0 kg"}
#                            ...
# 458     {"Height": "183.0 cm", "Weight": "83.0 kg"}
# 459     {"Height": "165.0 cm", "Weight": "52.0 kg"}
# 460      {"Height": "66.0 cm", "Weight": "17.0 kg"}
# 461     {"Height": "170.0 cm", "Weight": "57.0 kg"}
# 462     {"Height": "185.0 cm", "Weight": "81.0 kg"}
# Name: Measurements, Length: 463, dtype: object

# %%
# josn.loads() method can be used to parse a valid JSON string and convert it into a Python Dictionary. 
# It is mainly used for deserializing native string:

info['Measurements'] = info['Measurements'].apply(json.loads)
info.loc[0, 'Measurements']
# Out:
# {'Height': '203.0 cm', 'Weight': '441.0 kg'}

# %%
# Now that Measurements is an actual dictionary it can be unpacked into separate columns:

height_weight = info['Measurements'].apply(pd.Series)

height_weight
# Out:
#        Height    Weight
# 0    203.0 cm  441.0 kg
# 1    191.0 cm   65.0 kg
# 2    185.0 cm   90.0 kg
# 3    203.0 cm  441.0 kg
# 4    193.0 cm  122.0 kg
# ..        ...       ...
# 458  183.0 cm   83.0 kg
# 459  165.0 cm   52.0 kg
# 460   66.0 cm   17.0 kg
# 461  170.0 cm   57.0 kg
# 462  185.0 cm   81.0 kg
#
# [463 rows x 2 columns]

# %%
# Add height and weight columns to original data frame:

info = pd.concat((info, height_weight), axis = 1)
info.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements    Height    Weight
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}  203.0 cm  441.0 kg
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  191.0 cm   65.0 kg
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}  185.0 cm   90.0 kg
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}  203.0 cm  441.0 kg
# ...

# %%
# Remove the orginal Meaurements column:

info = info.drop(columns = ['Measurements'])

info.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color    Height    Weight
# 0    No Hair    yellow    Unknown  203.0 cm  441.0 kg
# 1    No Hair      blue       blue  191.0 cm   65.0 kg
# 2    No Hair      blue        red  185.0 cm   90.0 kg
# 3    No Hair     green    Unknown  203.0 cm  441.0 kg
# 4    No Hair      blue    Unknown  193.0 cm  122.0 kg

# %%
# Removing the spacing and units to make height and weight numeric:

info['Height'] = info['Height'].str.replace(' cm', '')
info['Weight'] = info['Weight'].str.replace(' kg', '')

info.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color Height Weight
# 0    No Hair    yellow    Unknown  203.0  441.0
# 1    No Hair      blue       blue  191.0   65.0
# 2    No Hair      blue        red  185.0   90.0
# 3    No Hair     green    Unknown  203.0  441.0
# 4    No Hair      blue    Unknown  193.0  122.0

# %%
# Converting columns to numeric:

info['Height'] = pd.to_numeric(info['Height'])
info['Weight'] = pd.to_numeric(info['Weight'])

info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hero|Publisher  463 non-null    object
#  1   Gender          463 non-null    object
#  2   Race            463 non-null    object
#  3   Alignment       463 non-null    object
#  4   Hair color      463 non-null    object
#  5   Eye color       463 non-null    object
#  6   Skin color      463 non-null    object
#  7   Height          463 non-null    float64
#  8   Weight          463 non-null    float64
# dtypes: float64(2), object(7)
# memory usage: 32.7+ KB

# %%
hero_pub = info['Hero|Publisher'].str.split('|', expand = True)
info[['Hero', 'Publisher']] = hero_pub

info.drop(columns='Hero|Publisher', inplace = True)

info
# Out:
#      Gender               Race Alignment        Hair color Eye color  \
# 0      Male              Human      good           No Hair    yellow
# 1      Male      Icthyo Sapien      good           No Hair      blue
# 2      Male            Ungaran      good           No Hair      blue
# 3      Male  Human / Radiation       bad           No Hair     green
# 4      Male              Human       bad           No Hair      blue
# ..      ...                ...       ...               ...       ...
# 458    Male              Human      good             Blond      blue
# 459  Female              Human      good  Strawberry Blond      blue
# 460    Male     Yoda's species      good             White     brown
# 461  Female              Human      good             Black      blue
# 462    Male            Unknown       bad             Brown       red
#
#     Skin color  Height  Weight             Hero          Publisher
# 0      Unknown   203.0   441.0           A-Bomb      Marvel Comics
# ...

# %%
info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  Height  \
# 0   Male              Human      good    No Hair    yellow    Unknown   203.0
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue   191.0
# 2   Male            Ungaran      good    No Hair      blue        red   185.0
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown   203.0
# 4   Male              Human       bad    No Hair      blue    Unknown   193.0
#
#    Weight           Hero          Publisher
# 0   441.0         A-Bomb      Marvel Comics
# 1    65.0     Abe Sapien  Dark Horse Comics
# 2    90.0       Abin Sur          DC Comics
# 3   441.0    Abomination      Marvel Comics
# 4   122.0  Absorbing Man      Marvel Comics

# %%
info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      463 non-null    object
#  1   Race        463 non-null    object
#  2   Alignment   463 non-null    object
#  3   Hair color  463 non-null    object
#  4   Eye color   463 non-null    object
#  5   Skin color  463 non-null    object
#  6   Height      463 non-null    float64
#  7   Weight      463 non-null    float64
#  8   Hero        463 non-null    object
#  9   Publisher   463 non-null    object
# dtypes: float64(2), object(8)
# memory usage: 36.3+ KB

# %%
# Import Powers DataFrame as pdf

pdf = pd.read_csv('C:\\Users\\jnate\\OneDrive\\Documents\\Data Enrichment\\Applying-Advanced-Transformations-Core-\\superhero_powers.csv')
pdf.head(5)
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
# Check for duplciates:

pdf.duplicated().sum()
# Out:
# 0

# %%
# Check for missing values:

pdf.isna().sum()
# Out:
# hero_names    0
# Powers        0
# dtype: int64

# %%
# Check datatypes:

pdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   hero_names  667 non-null    object
#  1   Powers      667 non-null    object
# dtypes: object(2)
# memory usage: 10.5+ KB

# %%
# Check values in Powers column:

pdf.loc[0, 'Powers']
# Out:
# 'Agility,Super Strength,Stamina,Super Speed'

# %%
# Abilities are stored as strings.
# Split on the comma ',':

pdf['powers_split'] = pdf['Powers'].str.split(',', expand = False)

# %%
# Separate row for each value in the in the list column:

exploded = pdf.explode('powers_split')

# %%
exploded
# Out:
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# ..         ...                                                ...
# 665    Zatanna  Cryokinesis,Telepathy,Magic,Fire Control,Proba...
# 666       Zoom  Super Speed,Intangibility,Time Travel,Time Man...
# 666       Zoom  Super Speed,Intangibility,Time Travel,Time Man...
# 666       Zoom  Super Speed,Intangibility,Time Travel,Time Man...
# 666       Zoom  Super Speed,Intangibility,Time Travel,Time Man...
#
#             powers_split
# 0                Agility
# 0         Super Strength
# 0                Stamina
# 0            Super Speed
# 1    Accelerated Healing
# ...

# %%
# Save unique values from exploded column:

columns = exploded['powers_split'].dropna().unique()

columns
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
# ...

# %%
# Create a new column for each of the unique vlaues:

for column in columns:
    pdf[column] = pdf['Powers'].str.contains(column)
pdf.head()
# Out:
# C:\Users\jnate\anaconda3\envs\dojo-env\lib\site-packages\ipykernel_launcher.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   after removing the cwd from sys.path.
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                         powers_split  Agility  Super Strength  \
# 0    [Agility, Super Strength, Stamina, Super Speed]     True            True
# ...

# %%
# Merging the info and powers DataFrames:

merged = pd.merge(info, pdf, left_on = 'Hero', right_on = 'hero_names')

merged.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  Height  \
# 0   Male              Human      good    No Hair    yellow    Unknown   203.0
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue   191.0
# 2   Male            Ungaran      good    No Hair      blue        red   185.0
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown   203.0
# 4   Male              Human       bad    No Hair      blue    Unknown   193.0
#
#    Weight           Hero          Publisher  ... Weather Control Omnipresent  \
# 0   441.0         A-Bomb      Marvel Comics  ...           False       False
# 1    65.0     Abe Sapien  Dark Horse Comics  ...           False       False
# 2    90.0       Abin Sur          DC Comics  ...           False       False
# 3   441.0    Abomination      Marvel Comics  ...           False       False
# 4   122.0  Absorbing Man      Marvel Comics  ...           False       False
#
# ...

# %% [markdown]
# ### Compare the average weight of super powers who have Super Speed to those who do not.

# %%
merged.groupby('Super Speed')['Weight'].mean()
# Out:
# Super Speed
# False    101.773585
# True     129.404040
# Name: Weight, dtype: float64

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (12,14))
sns.barplot(data = merged, x = 'Super Speed' , y = 'Weight', color = '#6a51a3', alpha = 0.5)
plt.title('Weights of Heroes with and without Super Speed\n', fontsize =24)
plt.ylabel('Weight\n\n', fontsize=16);
plt.xlabel('\n\nSuper Speed', fontsize=16);

# %% [markdown]
# ### A: heroes with Super Speed are heavier, on average, than those without it.

# %% [markdown]
# ### What is the average height of heroes for each publisher?

# %%
merged.groupby('Publisher')['Height'].mean()
# Out:
# Publisher
# DC Comics            181.923913
# Dark Horse Comics    176.909091
# George Lucas         159.600000
# Image Comics         211.000000
# Marvel Comics        191.546128
# Shueisha             171.500000
# Star Trek            181.500000
# Team Epic TV         180.750000
# Unknown              178.000000
# Name: Height, dtype: float64

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (12,14))
sns.barplot(data = merged, x = 'Publisher' , y = 'Height', color = 'deeppink', alpha = 0.5)
plt.axhline(y=211, color = 'red', alpha = .5, ls = 'dashed');

plt.title('Heights of Heroes by Publisher\n', fontsize =24)
plt.ylabel('Height\n\n', fontsize=16);
plt.xlabel('\n\nPublishing Company', fontsize=16);
plt.xticks(rotation=90);

# %% [markdown]
# ### A: Imagine Comics produce the tallest heroes on average and Lucas studios produce the shortest heroes on average.
